# %% [markdown]
# # 作業3 : 利用 RL 逃離迷宮
# > **說明**
#
# Using Q-learining or any reinforcement learning algorithm to find out the way to escape the maze.
#
# 請利用 Q-learning 或任何你知道的RL方法去逃離迷宮
#
# 請隨意修改這個 colab 的程式來完成訓練
#
# 數字僅供繪製地圖時參考用
#
# 迷宮本身為 21 * 11 的迷宮
#
# 起點左上角 (0,0) 終點為右下角 (20,10)
#
# X 表示牆壁位置(顏色為綠色方便區分) O 表示寶藏位置(顏色為橘色方便區分) S 表示起點位置 G 表示終點位置 黃色底色表示可能路徑 請利用以下程式碼將地圖設定完成
#
# 移動時不可穿過障礙物
#
# 注意事項:
#
# 訓練次數（MAX_EPISODES 參數）不得超過 1000 次。
#
# 以能到終點為主要作業目標 步數越少分數越高。
#
# 請自行將規則補在程式內，並制定良好的 Reward 讓你更快走完。
#
# 寶藏計分方式為參數 Score，每踩到一個寶箱 Score +1，每個寶箱只能獲得一次分數，每個 episode 需重置，且每回合都必須計算 Score 分數，最高 5 分。
#
# 文件內請附上你認為最好的一筆訓練結果（步數 + 寶藏），並將結果保存於 colab 輸出結果中。計分將以這筆訓練結果作為依據！

# %%
import numpy as np
import pandas as pd
import time

pd.set_option('display.max_rows', 300)

"""設定 x, y 軸長度，

範例為 40 * 30 的無障礙迷宮

並設定可行動動作為上下左右

目標位置在最右下角

以及各項參數設定

SCORE 為計算寶藏分數用

得分計算方法請自行補上
"""

# todo: 修改迷宮大小
from enum import Enum
WALLS = [4, 5, 7, 9, 22, 23, 25, 30, 31, 35, 39, 43, 45, 47, 49, 50, 51,
      53, 55, 57, 58, 59, 61, 65, 71, 74, 80, 85, 88, 90, 94, 97, 100,
      101, 102, 104, 109, 110, 111, 113, 114, 119, 120, 127, 128, 129, 132,
      134, 136, 141, 142, 143, 145, 151, 153, 155, 157, 158, 164, 166, 169,
      172, 176, 178, 181, 183, 186, 187, 190, 191, 193, 195, 196, 206, 211, 214, 226, 229]
N_STATES_x = 21
N_STATES_y = 11
GOAL = 230
START = 0
TREASURES = [6, 79, 170, 212, 227]

ACTIONS = ["left", "right", "up", "down"]

EPSILON = 0.9
ALPHA = 0.05
GAMMA = 0.9
MAX_EPISODES = 500
FRESH_TIME = 0

SCORE = 0

get_treasures = []
# class ACTIONS(Enum):
#   LEFT = -1
#   RIGHT = 1
#   UP = -N_STATES_x
#   DOWN = N_STATES_x

# %%
"""建立一開始的空Q table"""

def build_q_table(N_STATES_x, N_STATES_y, actions):
    table = pd.DataFrame(
        np.zeros((N_STATES_x * N_STATES_y, len(actions))),
        columns=actions,
    )
    return table

# %%
"""如何選擇動作"""

def choose_action(state, q_table):

    # 取table內index從state開始之後的資料
    state_actions = q_table.iloc[state, :]

    # 最一開始或是epsilon>0.9，隨機挑選一個action
    if (np.random.uniform() > EPSILON) or ((state_actions == 0).all()):
        action_name = np.random.choice(ACTIONS)

    # idxmax()回傳每一row中數值最大的index
    else:
        action_name = state_actions.idxmax()
    return action_name

# %%
"""Reward 設定

(以向右走為例 剩餘動作請自行補上)
"""

REWARD_TREASURE = 3
REWARD_GOAL = 5
REWARD_FORWARD = -2
REWARD_BAD = -3

def get_next_state(state, action):
  next_state = state
  if action == "right":
    next_state += 1
  elif action == "left":
    next_state += -1
  elif action == "up":
    next_state += -N_STATES_x
  elif action == "down":
    next_state += N_STATES_x
  if next_state in WALLS or \
     next_state < 0 or \
     next_state > 230 :
    return [state, False]
  elif next_state % 21 == 0 and \
       action == "right":
    return [state, False]
  elif (next_state + 1) % 21 == 0 and \
       action == "left":
    return [state, False]
  elif next_state == GOAL:
    return [next_state, True]
  else:
    return [next_state, False]

def get_env_feedback(state, action, get_treasures):
#   print(f"now:{state}")
#   print(f"action:{action}")
  next_state, result = get_next_state(state, action)
  if next_state == state:
    reward = REWARD_BAD
  elif result:
    reward = REWARD_GOAL
  elif next_state in TREASURES and next_state not in get_treasures:
    reward = REWARD_TREASURE
    get_treasures.append(next_state)
    # TREASURES.remove(next_state)
    # print("get treasure!!!!!")
  else:
    reward = REWARD_FORWARD
  return next_state, reward, get_treasures

# %%
"""利用選擇的動作更新畫面
可自行選擇是否印出
"""

def update_env(state, episode, step_counter):

    # 環境地圖初始化 "-"代表空
    env_map = [["-" for i in range(N_STATES_x)] for j in range(N_STATES_y)]
    # T代表目標位置
    env_map[int(GOAL / N_STATES_x)][GOAL % N_STATES_x] = "T"
    # 顯示牆壁
    for wall in WALLS:
      env_map[int(wall / N_STATES_x)][wall % N_STATES_x] = "X"
    for treasure in TREASURES:
      env_map[int(treasure / N_STATES_x)][treasure % N_STATES_x] = "$$"
    result = []
    # 如果走到終點表示當前的回合已結束
    if state == 230:
        # 紀錄回合數、步數
        interaction = f"Episode:{episode + 1} total_steps:{step_counter}"
        # interaction = "Episode %s: total_steps=%s" % (episode + 1, step_counter, )
        result.append(interaction)
        print(result)
        print("\r", end="")

        # print("=============================")
    # 如果不是走到終點的話，標記目前的位置為 "o"
    else:
      env_map[int(state / N_STATES_x)][int(state % N_STATES_x)] = "o"
      # time.sleep(FRESH_TIME)

# %%
"""# 更新 Q table"""
def rl():
    # 創建Q table
    q_table = build_q_table(N_STATES_x, N_STATES_y, ACTIONS)
    for episode in range(MAX_EPISODES):
        # TREASURES = [6, 79, 170, 212, 227]
        step_counter = 0
        S = 0
        is_terminated = False
        path = []
        get_treasures = []
        update_env(S, episode, step_counter)
        while not is_terminated:
            A = choose_action(S, q_table)
            path.append(S)
            S_, R, get_treasures = get_env_feedback(S, A, get_treasures)
            # 從 q table 中獲取當前狀態和預測行動的Q值
            q_predict = q_table.loc[S, A]
            # 如果未到達終點
            if S_ != 230:
                # 計算目前的Q值：當前的 reward + 下一個 state 可以得到的最大Q值
                q_target = R + GAMMA * q_table.iloc[S_, :].max()
            # 到達終點
            else:
                # 目標Q值為當前 reward
                q_target = R
                is_terminated = True
            # 更新 Q table
            q_table.loc[S, A] += ALPHA * (q_target - q_predict)
            S = S_
            update_env(S, episode, step_counter + 1)
            step_counter += 1
        if step_counter < 400 and len(get_treasures) > 3:
            print(f"路線{path}")
            print(f"獲得寶藏{get_treasures}")
            print(f"分數:{len(get_treasures)}")
            time.sleep(2)
    return all, q_table

# %%
"""執行程式"""

if __name__ == "__main__":
    q_table = rl()
    print("\r\nQ-table:\n")
    print(q_table)
# Out:
# ['Episode:1 total_steps:3181']
# ['Episode:2 total_steps:5573']
# ['Episode:3 total_steps:4956']
# ['Episode:4 total_steps:4582']
# ['Episode:5 total_steps:3501']
# ['Episode:6 total_steps:2901']
# ['Episode:7 total_steps:2788']
# ['Episode:8 total_steps:2996']
# ['Episode:9 total_steps:1798']
# ['Episode:10 total_steps:2683']
# ['Episode:11 total_steps:2319']
# ['Episode:12 total_steps:2595']
# ['Episode:13 total_steps:1700']
# ['Episode:14 total_steps:2032']
# ['Episode:15 total_steps:2220']
# ['Episode:16 total_steps:2025']
# ['Episode:17 total_steps:1859']
# ['Episode:18 total_steps:1742']
# ['Episode:19 total_steps:1465']
# ['Episode:20 total_steps:1570']
# ['Episode:21 total_steps:1822']
# ['Episode:22 total_steps:1483']
# ['Episode:23 total_steps:1537']
# ['Episode:24 total_steps:1637']
# ['Episode:25 total_steps:1301']
# ['Episode:26 total_steps:1539']
# ['Episode:27 total_steps:1434']
# ['Episode:28 total_steps:1283']
# ['Episode:29 total_steps:1462']
# ['Episode:30 total_steps:1341']
# ['Episode:31 total_steps:1220']
# ['Episode:32 total_steps:1354']
# ['Episode:33 total_steps:976']
# ['Episode:34 total_steps:1425']
# ['Episode:35 total_steps:1114']
# ['Episode:36 total_steps:1244']
# ['Episode:37 total_steps:1216']
# ['Episode:38 total_steps:1148']
# ['Episode:39 total_steps:1151']
# ['Episode:40 total_steps:1042']
# ['Episode:41 total_steps:1025']
# ['Episode:42 total_steps:1153']
# ['Episode:43 total_steps:1153']
# ['Episode:44 total_steps:897']
# ['Episode:45 total_steps:1084']
# ['Episode:46 total_steps:993']
# ['Episode:47 total_steps:1102']
# ['Episode:48 total_steps:1151']
# ['Episode:49 total_steps:831']
# ['Episode:50 total_steps:1006']
# ['Episode:51 total_steps:866']
# ['Episode:52 total_steps:926']
# ['Episode:53 total_steps:717']
# ['Episode:54 total_steps:1197']
# ['Episode:55 total_steps:925']
# ['Episode:56 total_steps:813']
# ['Episode:57 total_steps:824']
# ['Episode:58 total_steps:923']
# ['Episode:59 total_steps:772']
# ['Episode:60 total_steps:1036']
# ['Episode:61 total_steps:761']
# ['Episode:62 total_steps:964']
# ['Episode:63 total_steps:856']
# ['Episode:64 total_steps:765']
# ['Episode:65 total_steps:813']
# ['Episode:66 total_steps:833']
# ['Episode:67 total_steps:799']
# ['Episode:68 total_steps:843']
# ['Episode:69 total_steps:667']
# ['Episode:70 total_steps:900']
# ['Episode:71 total_steps:745']
# ['Episode:72 total_steps:781']
# ['Episode:73 total_steps:961']
# ['Episode:74 total_steps:594']
# ['Episode:75 total_steps:691']
# ['Episode:76 total_steps:867']
# ['Episode:77 total_steps:760']
# ['Episode:78 total_steps:629']
# ['Episode:79 total_steps:808']
# ['Episode:80 total_steps:693']
# ['Episode:81 total_steps:471']
# ['Episode:82 total_steps:914']
# ['Episode:83 total_steps:789']
# ['Episode:84 total_steps:597']
# ['Episode:85 total_steps:741']
# ['Episode:86 total_steps:754']
# ['Episode:87 total_steps:617']
# ['Episode:88 total_steps:532']
# ['Episode:89 total_steps:774']
# ['Episode:90 total_steps:870']
# ['Episode:91 total_steps:504']
# ['Episode:92 total_steps:816']
# ['Episode:93 total_steps:532']
# ['Episode:94 total_steps:664']
# ['Episode:95 total_steps:615']
# ['Episode:96 total_steps:819']
# ['Episode:97 total_steps:463']
# ['Episode:98 total_steps:733']
# ['Episode:99 total_steps:559']
# ['Episode:100 total_steps:597']
# ['Episode:101 total_steps:692']
# ['Episode:102 total_steps:554']
# ['Episode:103 total_steps:599']
# ['Episode:104 total_steps:713']
# ['Episode:105 total_steps:518']
# ['Episode:106 total_steps:656']
# ['Episode:107 total_steps:588']
# ['Episode:108 total_steps:610']
# ['Episode:109 total_steps:559']
# ['Episode:110 total_steps:678']
# ['Episode:111 total_steps:461']
# ['Episode:112 total_steps:649']
# ['Episode:113 total_steps:718']
# ['Episode:114 total_steps:552']
# ['Episode:115 total_steps:508']
# ['Episode:116 total_steps:608']
# ['Episode:117 total_steps:547']
# ['Episode:118 total_steps:629']
# ['Episode:119 total_steps:631']
# ['Episode:120 total_steps:540']
# ['Episode:121 total_steps:637']
# ['Episode:122 total_steps:597']
# ['Episode:123 total_steps:550']
# ['Episode:124 total_steps:585']
# ['Episode:125 total_steps:500']
# ['Episode:126 total_steps:560']
# ['Episode:127 total_steps:459']
# ['Episode:128 total_steps:605']
# ['Episode:129 total_steps:478']
# ['Episode:130 total_steps:525']
# ['Episode:131 total_steps:603']
# ['Episode:132 total_steps:553']
# ['Episode:133 total_steps:469']
# ['Episode:134 total_steps:475']
# ['Episode:135 total_steps:489']
# ['Episode:136 total_steps:520']
# ['Episode:137 total_steps:529']
# ['Episode:138 total_steps:594']
# ['Episode:139 total_steps:535']
# ['Episode:140 total_steps:496']
# ['Episode:141 total_steps:424']
# ['Episode:142 total_steps:532']
# ['Episode:143 total_steps:555']
# ['Episode:144 total_steps:389']
# ['Episode:145 total_steps:615']
# ['Episode:146 total_steps:471']
# ['Episode:147 total_steps:485']
# ['Episode:148 total_steps:394']
# ['Episode:149 total_steps:769']
# ['Episode:150 total_steps:419']
# ['Episode:151 total_steps:535']
# ['Episode:152 total_steps:423']
# ['Episode:153 total_steps:440']
# ['Episode:154 total_steps:528']
# ['Episode:155 total_steps:476']
# ['Episode:156 total_steps:552']
# ['Episode:157 total_steps:427']
# ['Episode:158 total_steps:401']
# ['Episode:159 total_steps:558']
# ['Episode:160 total_steps:437']
# ['Episode:161 total_steps:585']
# ['Episode:162 total_steps:395']
# ['Episode:163 total_steps:409']
# ['Episode:164 total_steps:659']
# ['Episode:165 total_steps:485']
# ['Episode:166 total_steps:464']
# ['Episode:167 total_steps:356']
# ['Episode:168 total_steps:354']
# ['Episode:169 total_steps:627']
# ['Episode:170 total_steps:400']
# ['Episode:171 total_steps:283']
# ['Episode:172 total_steps:582']
# ['Episode:173 total_steps:577']
# ['Episode:174 total_steps:386']
# ['Episode:175 total_steps:502']
# ['Episode:176 total_steps:301']
# ['Episode:177 total_steps:506']
# ['Episode:178 total_steps:628']
# ['Episode:179 total_steps:428']
# ['Episode:180 total_steps:455']
# ['Episode:181 total_steps:387']
# ['Episode:182 total_steps:550']
# ['Episode:183 total_steps:427']
# ['Episode:184 total_steps:377']
# ['Episode:185 total_steps:388']
# ['Episode:186 total_steps:619']
# ['Episode:187 total_steps:447']
# ['Episode:188 total_steps:337']
# ['Episode:189 total_steps:434']
# ['Episode:190 total_steps:415']
# ['Episode:191 total_steps:312']
# ['Episode:192 total_steps:476']
# ['Episode:193 total_steps:559']
# ['Episode:194 total_steps:470']
# ['Episode:195 total_steps:409']
# ['Episode:196 total_steps:311']
# ['Episode:197 total_steps:294']
# ['Episode:198 total_steps:418']
# ['Episode:199 total_steps:408']
# ['Episode:200 total_steps:517']
# ['Episode:201 total_steps:433']
# ['Episode:202 total_steps:474']
# ['Episode:203 total_steps:361']
# ['Episode:204 total_steps:524']
# ['Episode:205 total_steps:442']
# ['Episode:206 total_steps:253']
# ['Episode:207 total_steps:397']
# ['Episode:208 total_steps:397']
# ['Episode:209 total_steps:465']
# ['Episode:210 total_steps:335']
# ['Episode:211 total_steps:455']
# ['Episode:212 total_steps:526']
# ['Episode:213 total_steps:391']
# 路線[0, 1, 2, 2, 3, 24, 3, 2, 3, 24, 3, 2, 1, 0, 21, 21, 0, 21, 42, 63, 64, 64, 64, 63, 42, 21, 42, 63, 64, 63, 63, 84, 105, 126, 105, 84, 84, 84, 63, 84, 105, 106, 105, 126, 147, 168, 189, 189, 210, 210, 189, 189, 168, 147, 148, 149, 170, 149, 170, 149, 170, 149, 170, 149, 170, 149, 170, 149, 170, 171, 192, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 192, 171, 170, 149, 170, 170, 149, 170, 149, 170, 149, 150, 171, 150, 149, 170, 149, 170, 170, 149, 170, 149, 170, 149, 170, 149, 170, 149, 149, 170, 149, 170, 149, 148, 147, 168, 189, 210, 189, 168, 147, 126, 126, 105, 106, 107, 108, 87, 108, 107, 106, 107, 86, 107, 108, 108, 87, 66, 67, 46, 67, 68, 69, 70, 69, 48, 27, 28, 27, 26, 27, 6, 27, 6, 27, 6, 27, 26, 27, 6, 27, 6, 27, 6, 27, 6, 27, 26, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 48, 69, 68, 89, 68, 69, 70, 91, 70, 91, 92, 91, 112, 91, 112, 133, 154, 154, 133, 154, 175, 174, 174, 173, 174, 175, 154, 154, 175, 174, 173, 194, 173, 152, 131, 130, 131, 152, 173, 194, 215, 194, 215, 216, 217, 218, 197, 197, 198, 197, 198, 177, 156, 135, 156, 177, 198, 199, 220, 199, 199, 200, 179, 180, 179, 179, 180, 159, 180, 201, 180, 180, 159, 138, 159, 160, 159, 159, 138, 139, 140, 139, 160, 139, 118, 117, 138, 117, 96, 75, 54, 75, 76, 76, 77, 98, 77, 78, 99, 99, 98, 99, 78, 79, 78, 79, 78, 79, 78, 79, 78, 79, 79, 78, 79, 78, 79, 78, 79, 78, 77, 56, 77, 78, 99, 99, 98, 99, 78, 79, 79, 78, 77, 76, 75, 54, 33, 54, 33, 34, 13, 14, 15, 16, 17, 18, 19, 20, 20, 41, 62, 83, 82, 103, 124, 125, 146, 167, 188, 209]
# 獲得寶藏[170, 212, 6, 79]
# 分數:4
# ['Episode:214 total_steps:376']
# ['Episode:215 total_steps:420']
# ['Episode:216 total_steps:478']
# ['Episode:217 total_steps:378']
# ['Episode:218 total_steps:418']
# ['Episode:219 total_steps:405']
# ['Episode:220 total_steps:447']
# ['Episode:221 total_steps:409']
# ['Episode:222 total_steps:463']
# ['Episode:223 total_steps:229']
# ['Episode:224 total_steps:536']
# ['Episode:225 total_steps:339']
# ['Episode:226 total_steps:365']
# ['Episode:227 total_steps:630']
# ['Episode:228 total_steps:294']
# ['Episode:229 total_steps:414']
# ['Episode:230 total_steps:309']
# ['Episode:231 total_steps:478']
# ['Episode:232 total_steps:405']
# ['Episode:233 total_steps:533']
# ['Episode:234 total_steps:183']
# ['Episode:235 total_steps:465']
# ['Episode:236 total_steps:286']
# ['Episode:237 total_steps:324']
# ['Episode:238 total_steps:317']
# ['Episode:239 total_steps:281']
# ['Episode:240 total_steps:530']
# ['Episode:241 total_steps:431']
# ['Episode:242 total_steps:401']
# ['Episode:243 total_steps:516']
# ['Episode:244 total_steps:320']
# ['Episode:245 total_steps:396']
# ['Episode:246 total_steps:400']
# ['Episode:247 total_steps:343']
# ['Episode:248 total_steps:295']
# ['Episode:249 total_steps:256']
# ['Episode:250 total_steps:435']
# ['Episode:251 total_steps:523']
# ['Episode:252 total_steps:272']
# ['Episode:253 total_steps:344']
# ['Episode:254 total_steps:392']
# ['Episode:255 total_steps:296']
# ['Episode:256 total_steps:384']
# ['Episode:257 total_steps:320']
# ['Episode:258 total_steps:506']
# ['Episode:259 total_steps:182']
# ['Episode:260 total_steps:360']
# ['Episode:261 total_steps:466']
# ['Episode:262 total_steps:423']
# ['Episode:263 total_steps:265']
# ['Episode:264 total_steps:298']
# ['Episode:265 total_steps:483']
# ['Episode:266 total_steps:129']
# ['Episode:267 total_steps:564']
# ['Episode:268 total_steps:333']
# ['Episode:269 total_steps:224']
# ['Episode:270 total_steps:453']
# ['Episode:271 total_steps:338']
# ['Episode:272 total_steps:438']
# ['Episode:273 total_steps:489']
# ['Episode:274 total_steps:278']
# ['Episode:275 total_steps:370']
# ['Episode:308 total_steps:190']
# ['Episode:309 total_steps:245']
# ['Episode:310 total_steps:564']
# ['Episode:311 total_steps:161']
# ['Episode:312 total_steps:394']
# ['Episode:313 total_steps:247']
# ['Episode:314 total_steps:255']
# ['Episode:315 total_steps:501']
# ['Episode:316 total_steps:217']
# ['Episode:317 total_steps:202']
# ['Episode:318 total_steps:472']
# ['Episode:319 total_steps:179']
# ['Episode:320 total_steps:265']
# ['Episode:321 total_steps:370']
# ['Episode:322 total_steps:445']
# ['Episode:323 total_steps:331']
# ['Episode:324 total_steps:480']
# ['Episode:325 total_steps:227']
# ['Episode:326 total_steps:275']
# ['Episode:327 total_steps:303']
# ['Episode:328 total_steps:388']
# ['Episode:329 total_steps:333']
# ['Episode:330 total_steps:628']
# ['Episode:331 total_steps:247']
# ['Episode:332 total_steps:113']
# ['Episode:333 total_steps:405']
# ['Episode:334 total_steps:205']
# ['Episode:335 total_steps:210']
# ['Episode:336 total_steps:316']
# ['Episode:337 total_steps:580']
# ['Episode:338 total_steps:109']
# ['Episode:339 total_steps:373']
# ['Episode:340 total_steps:316']
# ['Episode:341 total_steps:186']
# ['Episode:342 total_steps:652']
# ['Episode:343 total_steps:142']
# ['Episode:344 total_steps:186']
# ['Episode:345 total_steps:435']
# ['Episode:346 total_steps:503']
# ['Episode:347 total_steps:194']
# ['Episode:348 total_steps:528']
# ['Episode:349 total_steps:353']
# ['Episode:350 total_steps:337']
# ['Episode:351 total_steps:525']
# ['Episode:352 total_steps:180']
# ['Episode:353 total_steps:235']
# ['Episode:354 total_steps:220']
# ['Episode:355 total_steps:295']
# ['Episode:356 total_steps:421']
# ['Episode:357 total_steps:315']
# ['Episode:358 total_steps:142']
# ['Episode:359 total_steps:544']
# ['Episode:360 total_steps:449']
# ['Episode:361 total_steps:237']
# ['Episode:362 total_steps:153']
# ['Episode:363 total_steps:642']
# ['Episode:364 total_steps:245']
# ['Episode:365 total_steps:216']
# ['Episode:366 total_steps:154']
# ['Episode:367 total_steps:397']
# ['Episode:368 total_steps:249']
# ['Episode:369 total_steps:161']
# ['Episode:370 total_steps:570']
# ['Episode:371 total_steps:306']
# ['Episode:372 total_steps:624']
# ['Episode:373 total_steps:276']
# ['Episode:374 total_steps:138']
# ['Episode:375 total_steps:308']
# ['Episode:376 total_steps:168']
# ['Episode:377 total_steps:374']
# ['Episode:378 total_steps:265']
# ['Episode:379 total_steps:357']
# 路線[0, 1, 2, 3, 24, 3, 2, 1, 0, 21, 21, 42, 21, 0, 1, 2, 1, 0, 21, 42, 63, 64, 63, 84, 105, 126, 147, 148, 149, 170, 149, 170, 149, 170, 149, 170, 149, 170, 171, 192, 213, 212, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 212, 213, 212, 213, 212, 213, 212, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 212, 213, 213, 212, 212, 213, 212, 213, 192, 171, 150, 149, 170, 149, 170, 149, 170, 171, 170, 149, 170, 149, 170, 149, 170, 149, 148, 147, 126, 105, 106, 107, 108, 87, 86, 87, 66, 87, 108, 107, 86, 107, 86, 87, 66, 67, 46, 67, 68, 89, 68, 67, 66, 67, 68, 69, 48, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 6, 27, 6, 27, 6, 27, 6, 27, 6, 6, 27, 6, 27, 6, 27, 6, 6, 27, 6, 27, 6, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 6, 27, 28, 27, 6, 27, 48, 69, 70, 91, 112, 133, 154, 175, 174, 173, 194, 215, 194, 215, 216, 215, 216, 217, 216, 217, 218, 197, 198, 199, 198, 199, 220, 221, 222, 223, 224, 225, 204, 225, 224, 203, 224, 224, 223, 222, 221, 222, 201, 202, 223, 202, 202, 203, 202, 223, 224, 225, 204, 205, 184, 163, 162, 163, 162, 161, 182, 161, 160, 159, 138, 139, 118, 117, 118, 139, 118, 117, 96, 95, 116, 137, 137, 138, 117, 116, 117, 118, 117, 96, 75, 76, 77, 98, 98, 99, 98, 99, 99, 78, 99, 98, 98, 77, 78, 79, 78, 79, 78, 79, 79, 78, 79, 78, 79, 78, 79, 78, 79, 78, 79, 78, 79, 78, 79, 79, 79, 78, 79, 78, 77, 56, 56, 56, 77, 76, 76, 75, 54, 54, 33, 12, 11, 10, 10, 10, 11, 11, 12, 13, 14, 14, 15, 16, 17, 18, 19, 18, 19, 40, 41, 40, 41, 62, 83, 82, 103, 124, 125, 146, 167, 188, 209]
# 獲得寶藏[170, 212, 6, 79]
# 分數:4
# ['Episode:380 total_steps:660']
# ['Episode:381 total_steps:155']
# ['Episode:382 total_steps:416']
# ['Episode:383 total_steps:146']
# ['Episode:384 total_steps:357']
# ['Episode:385 total_steps:456']
# ['Episode:386 total_steps:162']
# ['Episode:387 total_steps:160']
# ['Episode:388 total_steps:510']
# ['Episode:389 total_steps:370']
# ['Episode:390 total_steps:306']
# ['Episode:391 total_steps:205']
# ['Episode:392 total_steps:239']
# ['Episode:393 total_steps:456']
# ['Episode:394 total_steps:183']
# ['Episode:395 total_steps:389']
# ['Episode:396 total_steps:347']
# ['Episode:397 total_steps:260']
# ['Episode:398 total_steps:169']
# ['Episode:399 total_steps:343']
# ['Episode:400 total_steps:273']
# ['Episode:401 total_steps:202']
# ['Episode:402 total_steps:337']
# ['Episode:403 total_steps:357']
# ['Episode:404 total_steps:518']
# ['Episode:405 total_steps:150']
# ['Episode:406 total_steps:410']
# ['Episode:407 total_steps:200']
# ['Episode:408 total_steps:339']
# ['Episode:409 total_steps:141']
# ['Episode:410 total_steps:471']
# ['Episode:411 total_steps:317']
# ['Episode:412 total_steps:121']
# ['Episode:413 total_steps:179']
# ['Episode:414 total_steps:492']
# ['Episode:415 total_steps:361']
# ['Episode:416 total_steps:236']
# ['Episode:417 total_steps:122']
# ['Episode:418 total_steps:638']
# ['Episode:419 total_steps:451']
# ['Episode:420 total_steps:346']
# ['Episode:421 total_steps:591']
# ['Episode:422 total_steps:168']
# ['Episode:423 total_steps:250']
# ['Episode:424 total_steps:145']
# ['Episode:425 total_steps:260']
# ['Episode:426 total_steps:393']
# ['Episode:427 total_steps:178']
# ['Episode:428 total_steps:192']
# ['Episode:429 total_steps:118']
# ['Episode:430 total_steps:505']
# ['Episode:431 total_steps:206']
# ['Episode:432 total_steps:228']
# ['Episode:433 total_steps:709']
# ['Episode:434 total_steps:157']
# ['Episode:435 total_steps:131']
# ['Episode:436 total_steps:248']
# ['Episode:437 total_steps:357']
# ['Episode:438 total_steps:188']
# ['Episode:439 total_steps:221']
# ['Episode:440 total_steps:405']
# ['Episode:441 total_steps:177']
# ['Episode:442 total_steps:338']
# ['Episode:443 total_steps:220']
# ['Episode:444 total_steps:113']
# ['Episode:445 total_steps:618']
# ['Episode:446 total_steps:242']
# ['Episode:447 total_steps:622']
# ['Episode:448 total_steps:144']
# ['Episode:449 total_steps:212']
# ['Episode:450 total_steps:325']
# ['Episode:451 total_steps:278']
# ['Episode:452 total_steps:222']
# ['Episode:453 total_steps:153']
# ['Episode:454 total_steps:160']
# ['Episode:455 total_steps:461']
# ['Episode:456 total_steps:637']
# ['Episode:457 total_steps:219']
# ['Episode:458 total_steps:349']
# ['Episode:459 total_steps:140']
# ['Episode:460 total_steps:404']
# ['Episode:461 total_steps:119']
# ['Episode:462 total_steps:412']
# ['Episode:463 total_steps:185']
# ['Episode:464 total_steps:178']
# ['Episode:465 total_steps:226']
# ['Episode:466 total_steps:159']
# ['Episode:467 total_steps:202']
# ['Episode:468 total_steps:148']
# ['Episode:469 total_steps:525']
# ['Episode:470 total_steps:401']
# ['Episode:471 total_steps:347']
# ['Episode:472 total_steps:276']
# ['Episode:473 total_steps:407']
# ['Episode:474 total_steps:420']
# ['Episode:475 total_steps:120']
# ['Episode:476 total_steps:603']
# ['Episode:477 total_steps:340']
# ['Episode:478 total_steps:143']
# ['Episode:479 total_steps:150']
# ['Episode:480 total_steps:444']
# ['Episode:481 total_steps:221']
# ['Episode:482 total_steps:207']
# ['Episode:483 total_steps:236']
# ['Episode:484 total_steps:114']
# ['Episode:485 total_steps:539']
# ['Episode:486 total_steps:172']
# ['Episode:487 total_steps:627']
# ['Episode:488 total_steps:141']
# ['Episode:489 total_steps:170']
# ['Episode:490 total_steps:155']
# ['Episode:491 total_steps:132']
# ['Episode:492 total_steps:307']
# ['Episode:493 total_steps:103']
# ['Episode:494 total_steps:494']
# ['Episode:495 total_steps:173']
# ['Episode:496 total_steps:325']
# ['Episode:497 total_steps:438']
# ['Episode:498 total_steps:174']
# ['Episode:499 total_steps:239']
# ['Episode:500 total_steps:554']
#
# Q-table:
#
# (<built-in function all>,           left      right         up       down
# 0   -20.151829 -19.763180 -20.338812 -19.763471
# 1   -19.763629 -19.763176 -20.075940 -20.060122
# 2   -19.763719 -19.763330 -20.067735 -19.897527
# 3   -19.763769 -19.947694 -20.083587 -19.763596
# 4     0.000000   0.000000   0.000000   0.000000
# 5     0.000000   0.000000   0.000000   0.000000
# 6   -20.469624 -20.479365 -20.430004 -19.537533
